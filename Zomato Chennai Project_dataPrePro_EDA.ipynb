# %% [markdown]
# # Zomato Chennai Data Analysis Project
# ### Data Preprocessing & Exploratory Data Analysis

# %% [markdown]
# ## 1. Import relevant Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.io as pio

pio.renderers.default = 'svg'

# %% [markdown]
# ## 2. Data Collection

# %%
raw_data = pd.read_csv('Zomato_Chennai_Listing.csv')
raw_data
# Out:
#                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 12027  https://www.zomato.com/chennai/cks-sandwiches-...
# 12028  https://www.zomato.com/chennai/cks-sandwiches-...
# 12029  https://www.zomato.com/chennai/cks-sandwiches-...
# 12030  https://www.zomato.com/chennai/cks-sandwiches-...
# 12031  https://www.zomato.com/chennai/cks-sandwiches-...
#
#           Name of Restaurant  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 12027        CK's Sandwiches
# 12028        CK's Sandwiches
# ...

# %% [markdown]
# ## 3. Basic Informations of Raw Dataset

# %%
raw_data.shape
# Out:
# (12032, 12)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12032 entries, 0 to 12031
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Zomato URL             12032 non-null  object
#  1   Name of Restaurant     12032 non-null  object
#  2   Address                12032 non-null  object
#  3   Location               12032 non-null  object
#  4   Cuisine                12032 non-null  object
#  5   Top Dishes             12032 non-null  object
#  6   Price for 2            12032 non-null  float64
#  7   Dining Rating          6681 non-null   float64
#  8   Dining Rating Count    11812 non-null  object
#  9   Delivery Rating        6181 non-null   float64
#  10  Delivery Rating Count  11812 non-null  object
#  11  Features               12032 non-null  object
# dtypes: float64(3), object(9)
# memory usage: 1.1+ MB

# %%
raw_data.dtypes
# Out:
# Zomato URL                object
# Name of Restaurant        object
# Address                   object
# Location                  object
# Cuisine                   object
# Top Dishes                object
# Price for 2              float64
# Dining Rating            float64
# Dining Rating Count       object
# Delivery Rating          float64
# Delivery Rating Count     object
# Features                  object
# dtype: object

# %%
raw_data.isnull().sum()
# Out:
# Zomato URL                  0
# Name of Restaurant          0
# Address                     0
# Location                    0
# Cuisine                     0
# Top Dishes                  0
# Price for 2                 0
# Dining Rating            5351
# Dining Rating Count       220
# Delivery Rating          5851
# Delivery Rating Count     220
# Features                    0
# dtype: int64

# %%
raw_data.describe()
# Out:
#         Price for 2  Dining Rating  Delivery Rating
# count  12032.000000    6681.000000      6181.000000
# mean     397.611370       3.387756         3.805290
# std      332.045938       0.558181         0.374213
# min       40.000000       0.300000         0.300000
# 25%      200.000000       3.100000         3.600000
# 50%      300.000000       3.500000         3.900000
# 75%      450.000000       3.800000         4.000000
# max     5000.000000       4.900000         4.700000

# %%
raw_data.fillna('0', inplace=True)
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_11048\1879070660.py:1: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.

# %%
raw_data.head(20)
# Out:
#                                            Zomato URL  \
# 0   https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1   https://www.zomato.com/chennai/sukkubhai-biriy...
# 2   https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3         https://www.zomato.com/chennai/kfc-perambur
# 4   https://www.zomato.com/chennai/tasty-kitchen-p...
# 5   https://www.zomato.com/chennai/dine-n-fun-meda...
# 6   https://www.zomato.com/chennai/bai-veetu-kalya...
# 7   https://www.zomato.com/chennai/cafe-arabica-an...
# 8   https://www.zomato.com/chennai/savoury-sea-she...
# 9   https://www.zomato.com/chennai/sangeetha-veg-r...
# 10  https://www.zomato.com/chennai/mcdonalds-velac...
# 11  https://www.zomato.com/chennai/kovai-alankar-v...
# 12  https://www.zomato.com/chennai/hotel-al-buhari...
# 13  https://www.zomato.com/chennai/dindigul-thalap...
# 14  https://www.zomato.com/chennai/hotel-paramount...
# 15  https://www.zomato.com/chennai/welcome-hotel-p...
# ...

# %% [markdown]
# ## 4. Data Preprocessing

# %%
raw_data.replace(to_replace = ['None','Does not offer Dining','Not enough Delivery Reviews','Does not offer Delivery',
                                'Not enough Dining Reviews'],value = '0', inplace = True)
raw_data.head()
# Out:
#                                           Zomato URL     Name of Restaurant  \
# 0  https://www.zomato.com/chennai/yaa-mohaideen-b...  Yaa Mohaideen Briyani
# 1  https://www.zomato.com/chennai/sukkubhai-biriy...     Sukkubhai Biriyani
# 2  https://www.zomato.com/chennai/ss-hyderabad-bi...   SS Hyderabad Biryani
# 3        https://www.zomato.com/chennai/kfc-perambur                    KFC
# 4  https://www.zomato.com/chennai/tasty-kitchen-p...          Tasty Kitchen
#
#                                              Address     Location  \
# 0          336 & 338, Main Road, Pallavaram, Chennai   Pallavaram
# 1   New 14, Old 11/3Q, Railway Station Road, MKN ...      Alandur
# 2   98/339, Arcot Road, Opposite Gokulam Chit Fun...  Kodambakkam
# 3   10, Periyar Nagar, 70 Feet Road, Near Sheeba ...     Perambur
# 4   135B, SRP Colony, Peravallur, Near Perambur, ...     Perambur
#
#                                              Cuisine  \
# 0                                        ['Biryani']
# ...

# %%
raw_data.isnull().sum()
# Out:
# Zomato URL               0
# Name of Restaurant       0
# Address                  0
# Location                 0
# Cuisine                  0
# Top Dishes               0
# Price for 2              0
# Dining Rating            0
# Dining Rating Count      0
# Delivery Rating          0
# Delivery Rating Count    0
# Features                 0
# dtype: int64

# %%
raw_data.dtypes
# Out:
# Zomato URL                object
# Name of Restaurant        object
# Address                   object
# Location                  object
# Cuisine                   object
# Top Dishes                object
# Price for 2              float64
# Dining Rating             object
# Dining Rating Count       object
# Delivery Rating           object
# Delivery Rating Count     object
# Features                  object
# dtype: object

# %%
# Changing the datatypes
raw_data['Dining Rating'] = raw_data['Dining Rating'].astype('float64')
raw_data['Dining Rating Count'] = raw_data['Dining Rating Count'].astype('int64')
raw_data['Delivery Rating'] = raw_data['Delivery Rating'].astype('float64')
raw_data['Delivery Rating Count'] = raw_data['Delivery Rating Count'].astype('int64')

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12032 entries, 0 to 12031
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Zomato URL             12032 non-null  object
#  1   Name of Restaurant     12032 non-null  object
#  2   Address                12032 non-null  object
#  3   Location               12032 non-null  object
#  4   Cuisine                12032 non-null  object
#  5   Top Dishes             12032 non-null  object
#  6   Price for 2            12032 non-null  float64
#  7   Dining Rating          12032 non-null  float64
#  8   Dining Rating Count    12032 non-null  int64
#  9   Delivery Rating        12032 non-null  float64
#  10  Delivery Rating Count  12032 non-null  int64
#  11  Features               12032 non-null  object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Working with 'Cuisine', 'Top Dishes' & 'Features' columns

# %%
# Cuisine
raw_data['Cuisine'] = raw_data['Cuisine'].str.replace('[','')
raw_data.head(5)
raw_data['Cuisine'] = raw_data['Cuisine'].str.replace(']','')
raw_data.head(5)
raw_data['Cuisine'] = raw_data['Cuisine'].str.replace("'",'')
raw_data.head(5)

# Top Dishes
raw_data['Top Dishes'] = raw_data['Top Dishes'].str.replace('[','')
raw_data.head(5)
raw_data['Top Dishes'] = raw_data['Top Dishes'].str.replace(']','')
raw_data.head(5)
raw_data['Top Dishes'] = raw_data['Top Dishes'].str.replace("'",'')
raw_data.head(5)

# Features
raw_data['Features'] = raw_data['Features'].str.replace('[','')
raw_data.head(5)
raw_data['Features'] = raw_data['Features'].str.replace(']','')
raw_data.head(5)
raw_data['Features'] = raw_data['Features'].str.replace("'",'')
raw_data.head(5)
# Out:
#                                           Zomato URL     Name of Restaurant  \
# 0  https://www.zomato.com/chennai/yaa-mohaideen-b...  Yaa Mohaideen Briyani
# 1  https://www.zomato.com/chennai/sukkubhai-biriy...     Sukkubhai Biriyani
# 2  https://www.zomato.com/chennai/ss-hyderabad-bi...   SS Hyderabad Biryani
# 3        https://www.zomato.com/chennai/kfc-perambur                    KFC
# 4  https://www.zomato.com/chennai/tasty-kitchen-p...          Tasty Kitchen
#
#                                              Address     Location  \
# 0          336 & 338, Main Road, Pallavaram, Chennai   Pallavaram
# 1   New 14, Old 11/3Q, Railway Station Road, MKN ...      Alandur
# 2   98/339, Arcot Road, Opposite Gokulam Chit Fun...  Kodambakkam
# 3   10, Periyar Nagar, 70 Feet Road, Near Sheeba ...     Perambur
# 4   135B, SRP Colony, Peravallur, Near Perambur, ...     Perambur
#
#                                              Cuisine  \
# 0                                            Biryani
# ...

# %%
# Deleting unwanted column
raw_data.drop(['Zomato URL','Address'],axis = 1, inplace = True)

# %%
raw_data
# Out:
#           Name of Restaurant         Location  \
# 0      Yaa Mohaideen Briyani       Pallavaram
# 1         Sukkubhai Biriyani          Alandur
# 2       SS Hyderabad Biryani      Kodambakkam
# 3                        KFC         Perambur
# 4              Tasty Kitchen         Perambur
# ...                      ...              ...
# 12027        CK's Sandwiches            Porur
# 12028        CK's Sandwiches         Kolathur
# 12029        CK's Sandwiches  Anna Nagar East
# 12030        CK's Sandwiches        Ramapuram
# 12031        CK's Sandwiches   Sholinganallur
#
#                                                  Cuisine  \
# 0                                                Biryani
# 1      Biryani,  North Indian,  Mughlai,  Desserts,  ...
# 2             Biryani,  North Indian,  Chinese,  Arabian
# 3           Burger,  Fast Food,  Finger Food,  Beverages
# 4      Chinese,  Biryani,  North Indian,  Chettinad, ...
# ...                                                  ...
# ...

# %%
# Check for the duplicates

raw_data[raw_data.duplicated()]
# Out:
#       Name of Restaurant              Location                        Cuisine  \
# 9103      Brownie Heaven              T. Nagar  Bakery,  Desserts,  Beverages
# 9995               ibaco  Kanchipuram District                      Ice Cream
# 10534         Cake Waves           Thiruvallur             Bakery,  Fast Food
# 11225       Pizza Square         Thiruvanmiyur              Pizza,  Fast Food
# 11361      Aavin Parlour           George Town                      Ice Cream
# 11390     The Cake Point             Mogappair                         Bakery
# 11489    Parantha Pundit             Mogappair       North Indian,  Beverages
# 11496    Parantha Pundit               Kovalam       North Indian,  Beverages
# 11553         Leo Coffee              Mylapore       Coffee,  Tea,  Beverages
# 11572         Leo Coffee       Anna Nagar East       Coffee,  Tea,  Beverages
# 11689         Hyku Foods                 Porur    Healthy Food,  South Indian
# ...

# %% [markdown]
# ### Copying Cleaned data to new dataframe

# %%
zomato_df = raw_data.copy()

# %%
zomato_df.head()
# Out:
#       Name of Restaurant     Location  \
# 0  Yaa Mohaideen Briyani   Pallavaram
# 1     Sukkubhai Biriyani      Alandur
# 2   SS Hyderabad Biryani  Kodambakkam
# 3                    KFC     Perambur
# 4          Tasty Kitchen     Perambur
#
#                                              Cuisine  \
# 0                                            Biryani
# 1  Biryani,  North Indian,  Mughlai,  Desserts,  ...
# 2         Biryani,  North Indian,  Chinese,  Arabian
# 3       Burger,  Fast Food,  Finger Food,  Beverages
# 4  Chinese,  Biryani,  North Indian,  Chettinad, ...
#
#                                           Top Dishes  Price for 2  \
# 0  Bread Halwa,  Chicken 65,  Mutton Biryani,  Ch...        500.0
# 1  Beef Biryani,  Beef Fry,  Paratha,  Paya,  Bri...       1000.0
# 2  Brinjal Curry,  Tandoori Chicken,  Chicken Gri...        500.0
# 3                                      Zinger Burger        500.0
# 4  Mutton Biryani,  Chicken Rice,  Tomato Rice,  ...        450.0
#
# ...

# %% [markdown]
# ## 5. Exploratory Data Analysis

# %% [markdown]
# #### Q1)  What are the top locations in Chennai with the highest number of restaurants?

# %%
top_locations_df = zomato_df.groupby(['Location']).agg({'Name of Restaurant':'count'}).rename(columns={'Name of Restaurant' : 'No of Restaurants'})
top_locations_df = top_locations_df.sort_values(by=['No of Restaurants'],ascending = False).reset_index()
top_locations_df.head(5)
# Out:
#     Location  No of Restaurants
# 0      Porur                418
# 1  Velachery                372
# 2   Ambattur                334
# 3   T. Nagar                315
# 4  Perungudi                288

# %%
fig = px.scatter(top_locations_df, x = 'No of Restaurants', y = 'Location', color = 'No of Restaurants',
                  title = 'Top locations with Most Restaurants')
fig.show()

# %% [markdown]
# #### Q2) What is the distribution of restaurant prices (Price for 2) across different locations?

# %%
location_rest_price_df = zomato_df.groupby(['Location'])['Price for 2'].mean().reset_index()
location_rest_price_df = location_rest_price_df.rename(columns={'Price for 2' : 'Average Price'})
location_rest_price_df
# Out:
#                                               Location  Average Price
# 0     InterContinental Chennai Mahabalipuram Resort...    1500.000000
# 1                                        Abhiramapuram     228.571429
# 2                          Abu Sarovar Portico, Egmore    1000.000000
# 3                                           Adambakkam     291.025641
# 4                                                Adyar     443.550000
# ..                                                 ...            ...
# 263                              Vivira Mall, Navallur     500.000000
# 264                                       Washermenpet     291.735537
# 265             WelcomHotel, RK Salai (Cathedral Road)    2075.000000
# 266                                      West Mambalam     267.846154
# 267                     Zone by The Park, Pallikaranai    1633.333333
#
# [268 rows x 2 columns]

# %%
fig = px.scatter(location_rest_price_df, x = 'Average Price', y = 'Location', color = 'Average Price',
                  title = 'Top locations with Most Restaurants').update_traces(marker={ "size" : 5, })
fig.show()

# %% [markdown]
# #### Q3) Which cuisines are the most popular in Chennai based on restaurant listings?

# %%
popular_cuisine_df = zomato_df['Cuisine'].value_counts().reset_index()
popular_cuisine_df.rename(columns={'count':'Counts of Restaurant'}, inplace=True)
popular_cuisine_df
# Out:
#                                                Cuisine  Counts of Restaurant
# 0                                         South Indian                   883
# 1                                            Fast Food                   295
# 2                                               Bakery                   266
# 3                               South Indian,  Chinese                   233
# 4                                              Biryani                   225
# ...                                                ...                   ...
# 2418  Rolls,  Mexican,  Pizza,  Chinese,  North Indian                     1
# 2419    Andhra,  Chinese,  North Indian,  South Indian                     1
# 2420                            Desserts,  Street Food                     1
# 2421            Chettinad,  South Indian,  Street Food                     1
# 2422                      Kerala,  Chettinad,  Biryani                     1
#
# [2423 rows x 2 columns]

# %% [markdown]
# #### Q4) How does the average price for two vary across different types of cuisines?

# %%
cuisine_rest_price_df = zomato_df.groupby(['Cuisine'])['Price for 2'].mean().reset_index()
cuisine_rest_price_df = cuisine_rest_price_df.rename(columns={'Price for 2':'Average Price'})
cuisine_rest_price_df
# Out:
#                                                 Cuisine  Average Price
# 0                                              American          500.0
# 1     American,  Andhra,  Asian,  Beverages,  Chetti...          800.0
# 2     American,  Arabian,  Italian,  Mexican,  Bever...          150.0
# 3                                        American,  BBQ          400.0
# 4                                American,  Continental         1000.0
# ...                                                 ...            ...
# 2418  Tibetan,  Mexican,  North Indian,  Chinese,  B...         1100.0
# 2419                                    Tibetan,  Momos          387.5
# 2420                                    Turkish,  Kebab          500.0
# 2421                                              Wraps          150.0
# 2422                                  Wraps,  Fast Food          300.0
#
# [2423 rows x 2 columns]

# %% [markdown]
# #### Q5) What are the most common features offered by restaurants (e.g., home delivery, table booking)?

# %%
most_features_offered_df = zomato_df['Features'].value_counts().reset_index()
most_features_offered_df.rename(columns={'count':'Counts of Restaurant'}, inplace=True)
most_features_offered_df
# Out:
#                                                Features  Counts of Restaurant
# 0                         Home Delivery, Indoor Seating                  2447
# 1                                         Delivery Only                   961
# 2                                         Home Delivery                   759
# 3                                        Indoor Seating                   569
# 4              Breakfast, Home Delivery, Indoor Seating                   485
# ...                                                 ...                   ...
# 1549  Home Delivery, Outdoor Seating, Table Reservat...                     1
# 1550  Home Delivery, Indoor Seating, Catering Availa...                     1
# 1551  Home Delivery, Kid Friendly, Free Parking, Ind...                     1
# 1552  Home Delivery, Full Bar Available, Smoking Are...                     1
# 1553  Home Delivery, Vegetarian Only, Group Meal, In...                     1
#
# [1554 rows x 2 columns]

# %% [markdown]
# #### Q6) What is the distribution of dining and delivery ratings across restaurants?

# %%
dining_delivery_dist_df = zomato_df.groupby('Name of Restaurant').agg({'Dining Rating':'mean','Delivery Rating':'mean'}).reset_index()
dining_delivery_dist_df.sort_values(by=['Dining Rating','Delivery Rating'],ascending=False,inplace =True)
dining_delivery_dist_df
# Out:
#                       Name of Restaurant  Dining Rating  Delivery Rating
# 2728                Gossip Fusion Bistro            4.9              4.3
# 3883                        Kabab Corner            4.9              4.3
# 5753               Prems Graama Bhojanam            4.9              4.1
# 982                              Bhangra            4.9              4.0
# 414   Amadora Gourmet Ice Cream & Sorbet            4.8              4.5
# ...                                  ...            ...              ...
# 8326                          Zan Shakes            0.0              0.0
# 8327                        Zara Kitchen            0.0              0.0
# 8332                      Zebra crossing            0.0              0.0
# 8355                Zoying Smoothies.com            0.0              0.0
# 8356                               Zucca            0.0              0.0
#
# [8369 rows x 3 columns]

# %% [markdown]
# ### Q7) Is there a correlation between dining ratings and delivery ratings?

# %%
Corr_dining_delivery_df = zomato_df['Dining Rating'].corr(zomato_df['Dining Rating'])
Corr_dining_delivery_df
# Out:
# 1.0

# %%
correlation_matrix = zomato_df[['Dining Rating', 'Delivery Rating']].corr()
correlation_matrix
# Out:
#                  Dining Rating  Delivery Rating
# Dining Rating         1.000000         0.354457
# Delivery Rating       0.354457         1.000000

# %% [markdown]
# #### Answer : There is a strong relationship between Dining Ratings and Delivery Ratings.

# %% [markdown]
# #### Q8) Do restaurants with higher dining ratings also have higher delivery ratings?

# %%
DiningRating_DeliveryRating_df = zomato_df[['Dining Rating','Delivery Rating']].corr()
DiningRating_DeliveryRating_df
# Out:
#                  Dining Rating  Delivery Rating
# Dining Rating         1.000000         0.354457
# Delivery Rating       0.354457         1.000000

# %% [markdown]
# #### Answer : Yes, higher Dining Ratings also have higher Delivery Ratings. It is Positively correlated.
# - The correlation value is a number between -1 and 1:
# - A value closer to 1 means a strong positive relationship (higher dining ratings are associated with higher delivery ratings).
# - A value closer to -1 means a strong negative relationship (higher dining ratings are associated with lower delivery ratings).
# - A value close to 0 indicates little to no linear relationship between the two ratings.

# %% [markdown]
# #### Q9) Which restaurants have the highest dining ratings in Chennai?

# %%
high_DiningRating = zomato_df[zomato_df['Dining Rating'] > 4.0]
high_DiningRating
# Out:
#           Name of Restaurant         Location  \
# 0      Yaa Mohaideen Briyani       Pallavaram
# 1         Sukkubhai Biriyani          Alandur
# 2       SS Hyderabad Biryani      Kodambakkam
# 4              Tasty Kitchen         Perambur
# 5                 Dine N Fun       Medavakkam
# ...                      ...              ...
# 10028             Creamy Inn  Anna Nagar West
# 10063    Cold Stone Creamery          Akkarai
# 10066         Pizza Republic         Tambaram
# 10135        Madrasi Biryani      Kelambakkam
# 10423         Kailash Parbat          Chetpet
#
#                                                  Cuisine  \
# 0                                                Biryani
# 1      Biryani,  North Indian,  Mughlai,  Desserts,  ...
# 2             Biryani,  North Indian,  Chinese,  Arabian
# 4      Chinese,  Biryani,  North Indian,  Chettinad, ...
# 5                  South Indian,  North Indian,  Chinese
# ...                                                  ...
# ...

# %%
High_dining_rating_df = high_DiningRating[['Name of Restaurant','Dining Rating']]
High_dining_rating_df.sort_values(by='Dining Rating',ascending= False, inplace = True)
High_dining_rating_df
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_11048\1194661687.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                     Name of Restaurant  Dining Rating
# 57                      Brownie Heaven            4.9
# 184               Gossip Fusion Bistro            4.9
# 105                            Bhangra            4.9
# 320                       Bombay Kulfi            4.9
# 192                       Kabab Corner            4.9
# ..                                 ...            ...
# 786              E-Sait Biryani Centre            4.1
# 794                          AKS Kabab            4.1
# 809  Vaasu's Ghuma Ghumalu Andhra Mess            4.1
# 818                          Hariyalii            4.1
# 694                              Annam            4.1
#
# ...

# %% [markdown]
# #### Q10) What are the most common cuisines in Chennai?

# %%
common_cuisine_df = zomato_df['Cuisine'].value_counts().reset_index()
common_cuisine_df.rename(columns={'count':'Counts of Restaurant'}, inplace=True)
common_cuisine_df
# Out:
#                                                Cuisine  Counts of Restaurant
# 0                                         South Indian                   883
# 1                                            Fast Food                   295
# 2                                               Bakery                   266
# 3                               South Indian,  Chinese                   233
# 4                                              Biryani                   225
# ...                                                ...                   ...
# 2418  Rolls,  Mexican,  Pizza,  Chinese,  North Indian                     1
# 2419    Andhra,  Chinese,  North Indian,  South Indian                     1
# 2420                            Desserts,  Street Food                     1
# 2421            Chettinad,  South Indian,  Street Food                     1
# 2422                      Kerala,  Chettinad,  Biryani                     1
#
# [2423 rows x 2 columns]

# %% [markdown]
# #### Answer : 'South Indian' is the most common cuisines in Chennai

# %% [markdown]
# #### Q11) Which regions or neighborhoods specialize in specific types of cuisine (e.g., Biryani, Chinese)?

# %%
zomato_df.head()
# Out:
#       Name of Restaurant     Location  \
# 0  Yaa Mohaideen Briyani   Pallavaram
# 1     Sukkubhai Biriyani      Alandur
# 2   SS Hyderabad Biryani  Kodambakkam
# 3                    KFC     Perambur
# 4          Tasty Kitchen     Perambur
#
#                                              Cuisine  \
# 0                                            Biryani
# 1  Biryani,  North Indian,  Mughlai,  Desserts,  ...
# 2         Biryani,  North Indian,  Chinese,  Arabian
# 3       Burger,  Fast Food,  Finger Food,  Beverages
# 4  Chinese,  Biryani,  North Indian,  Chettinad, ...
#
#                                           Top Dishes  Price for 2  \
# 0  Bread Halwa,  Chicken 65,  Mutton Biryani,  Ch...        500.0
# 1  Beef Biryani,  Beef Fry,  Paratha,  Paya,  Bri...       1000.0
# 2  Brinjal Curry,  Tandoori Chicken,  Chicken Gri...        500.0
# 3                                      Zinger Burger        500.0
# 4  Mutton Biryani,  Chicken Rice,  Tomato Rice,  ...        450.0
#
# ...

# %%
# Step 1: Split the 'Cuisine Type' column into individual cuisines  

zomato_df['Cuisine'] = zomato_df['Cuisine'].str.split(',')

# %%
# Step 2: Explode the list of cuisines into individual rows

exploded_df = zomato_df.explode('Cuisine')
exploded_df
# Out:
#           Name of Restaurant         Location         Cuisine  \
# 0      Yaa Mohaideen Briyani       Pallavaram         Biryani
# 1         Sukkubhai Biriyani          Alandur         Biryani
# 1         Sukkubhai Biriyani          Alandur    North Indian
# 1         Sukkubhai Biriyani          Alandur         Mughlai
# 1         Sukkubhai Biriyani          Alandur        Desserts
# ...                      ...              ...             ...
# 12027        CK's Sandwiches            Porur        Sandwich
# 12028        CK's Sandwiches         Kolathur        Sandwich
# 12029        CK's Sandwiches  Anna Nagar East        Sandwich
# 12030        CK's Sandwiches        Ramapuram        Sandwich
# 12031        CK's Sandwiches   Sholinganallur        Sandwich
#
#                                               Top Dishes  Price for 2  \
# 0      Bread Halwa,  Chicken 65,  Mutton Biryani,  Ch...        500.0
# 1      Beef Biryani,  Beef Fry,  Paratha,  Paya,  Bri...       1000.0
# ...

# %%
# Step 3: Group by 'Region' and 'Cuisine Type' and count the number of restaurants
cuisine_by_region = exploded_df.groupby(['Location','Cuisine']).size().reset_index(name='Restaurant Count')
cuisine_by_region
# Out:
#                                                Location         Cuisine  \
# 0      InterContinental Chennai Mahabalipuram Resort...     Finger Food
# 1                                         Abhiramapuram       Beverages
# 2                                         Abhiramapuram        Desserts
# 3                                         Abhiramapuram          Juices
# 4                                         Abhiramapuram           Pizza
# ...                                                 ...             ...
# 6119                     Zone by The Park, Pallikaranai    South Indian
# 6120                     Zone by The Park, Pallikaranai     Street Food
# 6121                     Zone by The Park, Pallikaranai        Bar Food
# 6122                     Zone by The Park, Pallikaranai    North Indian
# 6123                     Zone by The Park, Pallikaranai            Thai
#
#       Restaurant Count
# 0                    1
# 1                    2
# 2                    1
# ...

# %%
# Step 4: Find the most common cuisine in each region

dominant_cuisine_by_region = cuisine_by_region.groupby('Location').first().reset_index()
dominant_cuisine_by_region.head(20)
# Out:
#                                              Location      Cuisine  \
# 0    InterContinental Chennai Mahabalipuram Resort...  Finger Food
# 1                                       Abhiramapuram    Beverages
# 2                         Abu Sarovar Portico, Egmore      Chinese
# 3                                          Adambakkam          BBQ
# 4                                               Adyar     American
# 5                                             Akkarai          BBQ
# 6                                             Alandur       Andhra
# 7                       Aloft Chennai, Sholinganallur      Italian
# 8                                            Alwarpet     American
# 9                          Ambassador Pallava, Egmore      Chinese
# 10                                           Ambattur       Andhra
# 11                          Ambica Empire, Vadapalani      Chinese
# 12                            Ambit IT Park, Ambattur     American
# ...

# %%
fig = px.histogram(dominant_cuisine_by_region, x = 'Restaurant Count', y = 'Location', color = 'Cuisine',
                  title = 'Dominant Cuisine By Location')
fig.show()

# %% [markdown]
# #### Q12) What is the average price for two for popular cuisines like Biryani, Chinese, or North Indian?

# %%
specific_cuisine = ['Biryani', 'Chinese', 'North Indian']
pop_cuisine = exploded_df[exploded_df['Cuisine'].isin(specific_cuisine)]
pop_cuisine
# Out:
#           Name of Restaurant     Location       Cuisine  \
# 0      Yaa Mohaideen Briyani   Pallavaram       Biryani
# 1         Sukkubhai Biriyani      Alandur       Biryani
# 2       SS Hyderabad Biryani  Kodambakkam       Biryani
# 4              Tasty Kitchen     Perambur       Chinese
# 6         Bai Veetu Kalyanam     Navallur       Biryani
# ...                      ...          ...           ...
# 12014            Bowl Bazaar        Adyar  North Indian
# 12015            Bowl Bazaar   Medavakkam  North Indian
# 12016            Bowl Bazaar    Perungudi  North Indian
# 12017            Bowl Bazaar   Medavakkam  North Indian
# 12018            Bowl Bazaar  Ashok Nagar  North Indian
#
#                                               Top Dishes  Price for 2  \
# 0      Bread Halwa,  Chicken 65,  Mutton Biryani,  Ch...        500.0
# 1      Beef Biryani,  Beef Fry,  Paratha,  Paya,  Bri...       1000.0
# 2      Brinjal Curry,  Tandoori Chicken,  Chicken Gri...        500.0
# ...

# %%
pop_cuisine_ave = pop_cuisine.groupby('Cuisine')['Price for 2'].mean().reset_index(name='Average Price')
pop_cuisine_ave.sort_values(by=['Average Price'], ascending = False, inplace= True)
pop_cuisine_ave.head(11)
# Out:
#         Cuisine  Average Price
# 2  North Indian     549.059772
# 1       Chinese     427.335640
# 0       Biryani     386.135721

# %% [markdown]
# #### Q13) Is there any relationship between the price for two and the restaurant's rating (both dining and delivery)?

# %%
price_diningrating_df = zomato_df['Dining Rating'].corr(zomato_df['Price for 2'])
price_diningrating_df
# Out:
# 0.31631463626378004

# %% [markdown]
# #### Answer : Weak Positive correlation, there is 31% relationship between the 'Price for 2 & Dining Rating'

# %%
price_diningrating_df = zomato_df[['Dining Rating','Price for 2']].corr()
price_diningrating_df
# Out:
#                Dining Rating  Price for 2
# Dining Rating       1.000000     0.316315
# Price for 2         0.316315     1.000000

# %%
price_diningrating_df = zomato_df['Delivery Rating'].corr(zomato_df['Price for 2'])
price_diningrating_df
# Out:
# 0.02303683358469787

# %% [markdown]
# #### Answer :  There is only a 2% relationship between the 'Price for 2 & Dining Rating', which means there is no relation between both columns.

# %%
price_diningrating_df = zomato_df[['Delivery Rating','Price for 2']].corr()
price_diningrating_df
# Out:
#                  Delivery Rating  Price for 2
# Delivery Rating         1.000000     0.023037
# Price for 2             0.023037     1.000000

# %% [markdown]
# ### Q14) What is the distribution of prices among highly-rated restaurants (4.0 and above)?

# %%
high_rated_rest = zomato_df[(zomato_df['Dining Rating'] >= 4.0) & (zomato_df['Delivery Rating'] >= 4.0)]
high_rated_rest
# Out:
#           Name of Restaurant         Location  \
# 0      Yaa Mohaideen Briyani       Pallavaram
# 1         Sukkubhai Biriyani          Alandur
# 2       SS Hyderabad Biryani      Kodambakkam
# 3                        KFC         Perambur
# 4              Tasty Kitchen         Perambur
# ...                      ...              ...
# 9960                   Ibaco        Chromepet
# 10028             Creamy Inn  Anna Nagar West
# 10063    Cold Stone Creamery          Akkarai
# 10066         Pizza Republic         Tambaram
# 11035         Uzo Sandwiches          Potheri
#
#                                                  Cuisine  \
# 0                                              [Biryani]
# 1      [Biryani,   North Indian,   Mughlai,   Dessert...
# 2        [Biryani,   North Indian,   Chinese,   Arabian]
# 3      [Burger,   Fast Food,   Finger Food,   Beverages]
# 4      [Chinese,   Biryani,   North Indian,   Chettin...
# ...                                                  ...
# ...

# %%
highrate_rest_aveg_df = high_rated_rest.groupby(['Location','Name of Restaurant','Dining Rating','Delivery Rating'])['Price for 2'].mean().reset_index(name='Average Price')
highrate_rest_aveg_df = highrate_rest_aveg_df.sort_values(by=['Dining Rating', 'Delivery Rating'], ascending=False)
highrate_rest_aveg_df
# Out:
#             Location               Name of Restaurant  Dining Rating  \
# 380    West Mambalam                The Sandwich Shop            4.9
# 3              Adyar                     Bombay Kulfi            4.9
# 127           Egmore                     Kabab Corner            4.9
# 162         Kanathur             Gossip Fusion Bistro            4.9
# 297       Royapettah                   Brownie Heaven            4.9
# ..               ...                              ...            ...
# 343        Teynampet                      Ox & Tomato            4.0
# 351  Thousand Lights                       Lassi Shop            4.0
# 359         Vandalur                       Ambrocia's            4.0
# 366        Velachery  Kings Kulfi & Natural Ice Cream            4.0
# 379    West Mambalam                 O.S.B Hot & Chat            4.0
#
#      Delivery Rating  Average Price
# 380              4.4          300.0
# 3                4.3          200.0
# ...

# %% [markdown]
# ### Q15) Which features are most common in Chennai restaurants (e.g., home delivery, free parking)?

# %%
# Split the 'Features' column into individual cuisines 

zomato_df['Features'] = zomato_df['Features'].str.split(',')

# %%
# Explode the list of Features into individual rows

exploded_feature = zomato_df.explode(['Features'])
exploded_feature
# Out:
#           Name of Restaurant         Location  \
# 0      Yaa Mohaideen Briyani       Pallavaram
# 0      Yaa Mohaideen Briyani       Pallavaram
# 1         Sukkubhai Biriyani          Alandur
# 1         Sukkubhai Biriyani          Alandur
# 1         Sukkubhai Biriyani          Alandur
# ...                      ...              ...
# 12029        CK's Sandwiches  Anna Nagar East
# 12030        CK's Sandwiches        Ramapuram
# 12030        CK's Sandwiches        Ramapuram
# 12031        CK's Sandwiches   Sholinganallur
# 12031        CK's Sandwiches   Sholinganallur
#
#                                                  Cuisine  \
# 0                                              [Biryani]
# 0                                              [Biryani]
# 1      [Biryani,   North Indian,   Mughlai,   Dessert...
# 1      [Biryani,   North Indian,   Mughlai,   Dessert...
# 1      [Biryani,   North Indian,   Mughlai,   Dessert...
# ...                                                  ...
# ...

# %%
most_feature_rest_df = exploded_feature['Features'].value_counts().reset_index(name='Restaurant Count')
most_feature_rest_df.head(11)
# Out:
#                       Features  Restaurant Count
# 0               Indoor Seating              7668
# 1                Home Delivery              6788
# 2                    Breakfast              2579
# 3           Desserts and Bakes              2090
# 4                Home Delivery              1702
# 5              Vegetarian Only              1699
# 6                 Free Parking              1361
# 7                Delivery Only              1058
# 8              Outdoor Seating               736
# 9               Indoor Seating               728
# 10   Table booking recommended               504

# %%
fig = px.bar(most_feature_rest_df, x = 'Restaurant Count', y = 'Features', color = 'Restaurant Count',
            title = 'Most common Features in Chennai Restaurants')
fig.show()

# %% [markdown]
# ### Q16) Which areas in Chennai have the highest concentration of top-rated restaurants?

# %%
high_toprate_rest = high_rated_rest[(high_rated_rest['Dining Rating'] >= 4.5)]
high_toprate_rest
# Out:
#                       Name of Restaurant                             Location  \
# 24                        Eating Circles                             Alwarpet
# 37                          Shree Mithai                              Chetpet
# 50                           Andhikkadai                            Velachery
# 57                        Brownie Heaven                           Royapettah
# 59                                 Mezze                             Alwarpet
# 62    Amadora Gourmet Ice Cream & Sorbet                         Nungambakkam
# 67                         Pumpkin Tales                             Alwarpet
# 68          Sandy's Chocolate Laboratory                         Nungambakkam
# 70                          Little Italy                         Besant Nagar
# 75                       Fusilli Reasons                              Kilpauk
# 78                 Shri Rajasthani Dhaba                      Anna Nagar West
# ...

# %%
toprate_rest_areaslist = high_toprate_rest[['Location','Dining Rating']]

# %%
toprate_rest_areaslist
# Out:
#                                  Location  Dining Rating
# 24                               Alwarpet            4.7
# 37                                Chetpet            4.6
# 50                              Velachery            4.6
# 57                             Royapettah            4.9
# 59                               Alwarpet            4.7
# 62                           Nungambakkam            4.8
# 67                               Alwarpet            4.5
# 68                           Nungambakkam            4.5
# 70                           Besant Nagar            4.7
# 75                                Kilpauk            4.7
# 78                        Anna Nagar West            4.5
# 88                            Kotturpuram            4.7
# 92                        Thousand Lights            4.5
# 102        Phoenix Market City, Velachery            4.6
# 105          Mayajaal Multiplex, Kanathur            4.9
# ...

# %%
toprated_rest_counts = high_toprate_rest['Location'].value_counts().reset_index(name = 'Restaurant count')

# %%
toprated_rest_counts.head(11)
# Out:
#            Location  Restaurant count
# 0      Nungambakkam                 6
# 1          Alwarpet                 5
# 2             Adyar                 4
# 3      Besant Nagar                 3
# 4            Egmore                 3
# 5   Anna Nagar West                 2
# 6         Teynampet                 2
# 7   Anna Nagar East                 2
# 8       Kotturpuram                 1
# 9   Thousand Lights                 1
# 10         Taramani                 1

# %%
fig = px.histogram(toprated_rest_counts, x = 'Location', y = 'Restaurant count', color = 'Restaurant count',
            title = 'More No of Top Rated Restaurants in Chennai')
fig.show()
